# %% [markdown]
# # Importing Libraries

# %% [markdown]
# For Mathematical calulation and for data manipulation

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Importing Dataset.

# %%
fifa=pd.read_csv('/Users/nielspace/Downloads/FIFA 2018 Statistics.csv')

# %% [markdown]
# Checking and reading files

# %%
fifa.head()
# Out:
#          Date          Team      Opponent  Goal Scored  Ball Possession %  \
# 0  14-06-2018        Russia  Saudi Arabia            5                 40
# 1  14-06-2018  Saudi Arabia        Russia            0                 60
# 2  15-06-2018         Egypt       Uruguay            0                 43
# 3  15-06-2018       Uruguay         Egypt            1                 57
# 4  15-06-2018       Morocco          Iran            0                 64
#
#    Attempts  On-Target  Off-Target  Blocked  Corners    ...     Saves  \
# 0        13          7           3        3        6    ...         0
# 1         6          0           3        3        2    ...         2
# 2         8          3           3        2        0    ...         3
# 3        14          4           6        4        5    ...         3
# 4        13          3           6        4        5    ...         2
#
#    Pass Accuracy %  Passes  Distance Covered (Kms)  Fouls Committed  \
# ...

# %%
fifa.describe()
# Out:
#        Goal Scored  Ball Possession %   Attempts  On-Target  Off-Target  \
# count    96.000000          96.000000  96.000000  96.000000   96.000000
# mean      1.270833          50.000000  12.031250   3.770833    5.156250
# std       1.183031          10.538151   4.991473   2.169061    2.267984
# min       0.000000          28.000000   3.000000   0.000000    1.000000
# 25%       0.000000          42.000000   8.000000   2.000000    4.000000
# 50%       1.000000          50.000000  12.000000   3.000000    5.000000
# 75%       2.000000          58.000000  15.000000   5.000000    6.000000
# max       6.000000          72.000000  26.000000  12.000000   11.000000
#
#          Blocked    Corners   Offsides  Free Kicks      Saves  \
# count  96.000000  96.000000  96.000000   96.000000  96.000000
# mean    3.104167   4.541667   1.500000   14.979167   2.614583
# std     2.245366   2.366061   1.273206    4.502582   1.843165
# min     0.000000   0.000000   0.000000    5.000000   0.000000
# ...

# %%
fifa.isnull().sum() #checking null values
# Out:
# Date                       0
# Team                       0
# Opponent                   0
# Goal Scored                0
# Ball Possession %          0
# Attempts                   0
# On-Target                  0
# Off-Target                 0
# Blocked                    0
# Corners                    0
# Offsides                   0
# Free Kicks                 0
# Saves                      0
# Pass Accuracy %            0
# Passes                     0
# Distance Covered (Kms)     0
# Fouls Committed            0
# Yellow Card                0
# Yellow & Red               0
# Red                        0
# Man of the Match           0
# 1st Goal                  27
# dtype: int64

# %%
num_rows=fifa.shape[0]

# %%
num_rows
# Out:
# 96

# %%
count_nan=fifa.isnull().sum()

# %%
count_wo_nan=count_nan[count_nan==0]

# %%
count_wo_nan
# Out:
# Date                      0
# Team                      0
# Opponent                  0
# Goal Scored               0
# Ball Possession %         0
# Attempts                  0
# On-Target                 0
# Off-Target                0
# Blocked                   0
# Corners                   0
# Offsides                  0
# Free Kicks                0
# Saves                     0
# Pass Accuracy %           0
# Passes                    0
# Distance Covered (Kms)    0
# Fouls Committed           0
# Yellow Card               0
# Yellow & Red              0
# Red                       0
# Man of the Match          0
# dtype: int64

# %%
fifa=fifa[count_wo_nan.keys()]

# %%
fifa.head()
# Out:
#          Date          Team      Opponent  Goal Scored  Ball Possession %  \
# 0  14-06-2018        Russia  Saudi Arabia            5                 40
# 1  14-06-2018  Saudi Arabia        Russia            0                 60
# 2  15-06-2018         Egypt       Uruguay            0                 43
# 3  15-06-2018       Uruguay         Egypt            1                 57
# 4  15-06-2018       Morocco          Iran            0                 64
#
#    Attempts  On-Target  Off-Target  Blocked  Corners        ...         \
# 0        13          7           3        3        6        ...
# 1         6          0           3        3        2        ...
# 2         8          3           3        2        0        ...
# 3        14          4           6        4        5        ...
# 4        13          3           6        4        5        ...
#
#    Free Kicks  Saves  Pass Accuracy %  Passes  Distance Covered (Kms)  \
# ...

# %%
fifa=fifa.drop(['Date'],axis=1)

# %%
fifa.head()
# Out:
#            Team      Opponent  Goal Scored  Ball Possession %  Attempts  \
# 0        Russia  Saudi Arabia            5                 40        13
# 1  Saudi Arabia        Russia            0                 60         6
# 2         Egypt       Uruguay            0                 43         8
# 3       Uruguay         Egypt            1                 57        14
# 4       Morocco          Iran            0                 64        13
#
#    On-Target  Off-Target  Blocked  Corners  Offsides  Free Kicks  Saves  \
# 0          7           3        3        6         3          11      0
# 1          0           3        3        2         1          25      2
# 2          3           3        2        0         1           7      3
# 3          4           6        4        5         1          13      3
# 4          3           6        4        5         0          14      2
#
#    Pass Accuracy %  Passes  Distance Covered (Kms)  Fouls Committed  \
# ...

# %%
fifa['Team'].value_counts()
# Out:
# Japan             3
# Saudi Arabia      3
# Serbia            3
# Mexico            3
# Peru              3
# Australia         3
# Iceland           3
# Denmark           3
# Germany           3
# Nigeria           3
# Sweden            3
# Panama            3
# Portugal          3
# Morocco           3
# Belgium           3
# Switzerland       3
# Russia            3
# Uruguay           3
# Costa Rica        3
# Korea Republic    3
# Spain             3
# Iran              3
# Egypt             3
# Senegal           3
# Brazil            3
# France            3
# England           3
# Poland            3
# Tunisia           3
# Crotia            3
# Colombia          3
# Argentina         3
# Name: Team, dtype: int64

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Data_Mapping

# %%
country_mapping={'Nigeria':1,'France':2,'Portugal':3,'Belgium':4,'England':5,'Russia':6,'Egypt':7,'Spain':8,'Costa Rica':9,
'Japan':10,
'Switzerland':11,
'Denmark':12,
'Crotia':13,
'Australia':14,
'Brazil':15,
'Mexico':16,
'Colombia':17,          
'Saudi Arabia':18,
'Panama':19,
'Senegal':20,
'Morocco':21,
'Serbia':22,
'Germany':23,
'Uruguay':24,
'Iceland':25,
'Peru':26,
'Iran':27,
'Poland':28,
'Sweden':29,
'Korea Republic':30,
'Tunisia':31,           
'Argentina':32
                }

# %%
data=[fifa]
for dataset in data:
    dataset['team']=dataset['Team'].map(country_mapping)

# %%
for dataset in data:
    dataset['opponent']=dataset['Opponent'].map(country_mapping)

# %%
fifa.head()
# Out:
#            Team      Opponent  Goal Scored  Ball Possession %  Attempts  \
# 0        Russia  Saudi Arabia            5                 40        13
# 1  Saudi Arabia        Russia            0                 60         6
# 2         Egypt       Uruguay            0                 43         8
# 3       Uruguay         Egypt            1                 57        14
# 4       Morocco          Iran            0                 64        13
#
#    On-Target  Off-Target  Blocked  Corners  Offsides   ...     \
# 0          7           3        3        6         3   ...
# 1          0           3        3        2         1   ...
# 2          3           3        2        0         1   ...
# 3          4           6        4        5         1   ...
# 4          3           6        4        5         0   ...
#
#    Pass Accuracy %  Passes  Distance Covered (Kms)  Fouls Committed  \
# 0               78     306                     118               22
# ...

# %%
binary_mapping = {'Yes':1,'No':0}

# %%
for dataset in data:
    dataset['Binary_MOM']=dataset['Man of the Match'].map(binary_mapping)

# %%
fifa.head()
# Out:
#            Team      Opponent  Goal Scored  Ball Possession %  Attempts  \
# 0        Russia  Saudi Arabia            5                 40        13
# 1  Saudi Arabia        Russia            0                 60         6
# 2         Egypt       Uruguay            0                 43         8
# 3       Uruguay         Egypt            1                 57        14
# 4       Morocco          Iran            0                 64        13
#
#    On-Target  Off-Target  Blocked  Corners  Offsides    ...      Passes  \
# 0          7           3        3        6         3    ...         306
# 1          0           3        3        2         1    ...         511
# 2          3           3        2        0         1    ...         395
# 3          4           6        4        5         1    ...         589
# 4          3           6        4        5         0    ...         433
#
#    Distance Covered (Kms)  Fouls Committed  Yellow Card  Yellow & Red  Red  \
# ...

# %%
fifa_new=fifa.drop(['Red','Blocked','Team','Opponent','Fouls Committed',],axis=1)

# %%
fifa_new.head()
# Out:
#    Goal Scored  Ball Possession %  Attempts  On-Target  Off-Target  Corners  \
# 0            5                 40        13          7           3        6
# 1            0                 60         6          0           3        2
# 2            0                 43         8          3           3        0
# 3            1                 57        14          4           6        5
# 4            0                 64        13          3           6        5
#
#    Offsides  Free Kicks  Saves  Pass Accuracy %  Passes  \
# 0         3          11      0               78     306
# 1         1          25      2               86     511
# 2         1           7      3               78     395
# 3         1          13      3               86     589
# 4         0          14      2               86     433
#
#    Distance Covered (Kms)  Yellow Card  Yellow & Red Man of the Match  team  \
# 0                     118            0             0              Yes     6
# ...

# %% [markdown]
# # Data_Visualization

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
sb.pairplot(fifa_new.drop(['Man of the Match'], axis=1), hue='Binary_MOM')

# %%
def bar_chart(feature):
    MOM=fifa_new[fifa_new['Binary_MOM']==1][feature].value_counts()
    non_MOM=fifa_new[fifa_new['Binary_MOM']==0][feature].value_counts()
    df=pd.DataFrame([MOM, non_MOM])
    df.index=['Man of the match','Not man of the match']
    df.plot(kind='bar', stacked=True, figsize=(10,5))

# %%
bar_chart('Pass Accuracy %')

# %%
fifa_new.head(2)
# Out:
#    Goal Scored  Ball Possession %  Attempts  On-Target  Off-Target  Corners  \
# 0            5                 40        13          7           3        6
# 1            0                 60         6          0           3        2
#
#    Offsides  Free Kicks  Saves  Pass Accuracy %  Passes  \
# 0         3          11      0               78     306
# 1         1          25      2               86     511
#
#    Distance Covered (Kms)  Yellow Card  Yellow & Red Man of the Match  team  \
# 0                     118            0             0              Yes     6
# 1                     105            0             0               No    18
#
#    opponent  Binary_MOM
# 0        18           1
# 1         6           0

# %% [markdown]
# ### Droping/selecting features for modeling

# %%
model_df=fifa_new.loc[:,['Ball Possession %','Attempts','On-Target','Off-Target','Free Kicks','Pass Accuracy %','Passes','Binary_MOM']]

# %%
model_df.head()
# Out:
#    Ball Possession %  Attempts  On-Target  Off-Target  Free Kicks  \
# 0                 40        13          7           3          11
# 1                 60         6          0           3          25
# 2                 43         8          3           3           7
# 3                 57        14          4           6          13
# 4                 64        13          3           6          14
#
#    Pass Accuracy %  Passes  Binary_MOM
# 0               78     306           1
# 1               86     511           0
# 2               78     395           0
# 3               86     589           1
# 4               86     433           0

# %% [markdown]
# Final data-visualization

# %%
sb.pairplot(model_df,hue='Binary_MOM')

# %% [markdown]
# # Modelling

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, cross_val_score

# %%
k_fold = KFold(n_splits=40, shuffle=True, random_state=0)

# %%
train=model_df.drop(['Binary_MOM'],axis=1)

# %%
target=model_df.loc[:,['Binary_MOM']]

# %%
clf=RandomForestClassifier(n_estimators=100)

# %%
score_2 = cross_val_score(clf, train, target, cv=k_fold, n_jobs=1)
print(score_2)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
round(np.mean(score_2)*100,2)
# Out:
# 62.079999999999998

# %%
from sklearn.naive_bayes import GaussianNB

# %%
clf_2=GaussianNB()

# %%
score=cross_val_score(clf_2, train, target, cv=k_fold, n_jobs=4)
print(score)
round(np.mean(score)*100,2)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
